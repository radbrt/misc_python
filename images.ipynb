# %%
from PIL import Image
from matplotlib.pyplot import imshow
import numpy as np

# %%
im = Image.open('../Pictures/metadata.png')

# %%
# %matplotlib inline

# %%
imshow(np.asarray(im))

# %%
npimg = np.asarray(im)

# %%
npimg.shape
# Out:
# (1590, 2048, 3)

# %%
import matplotlib.pyplot as plt

# %%
f = npimg[:,:,1].flatten()


n, bins, patches = plt.hist(f)

plt.show()

# %%
f.shape
# Out:
# (3256320,)

# %%
imshow(npimg[:,:,0])

# %%
imshow(npimg[:,:,1])

# %%
imshow(npimg[:,:,2])
